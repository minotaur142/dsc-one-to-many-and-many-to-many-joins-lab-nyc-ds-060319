# %% [markdown]
# # One-to-Many and Many-to-Many Joins - Lab

# %% [markdown]
# ## Introduction

# %% [markdown]
# In this lab, you'll practice your knowledge on one-to-many and many-to-many relationships!

# %% [markdown]
# ## Objectives

# %% [markdown]
# You will be able to:
# - Query data using one-to-many and many-to-many joins
# - Predict the resulting size of one-to-many and many-to-many joins

# %% [markdown]
# ## One-to-Many and Many-to-Many Joins
# <img src='images/Database-Schema.png' width="600">

# %% [markdown]
# ## Connect to the Database

# %%
import pandas as pd
import sqlite3
conn = sqlite3.connect('data.sqlite', detect_types=sqlite3.PARSE_COLNAMES)
c = conn.cursor()

# %% [markdown]
# ## Employees and their Office (a One-to-One join)
#
# Return a list of all of the employees with their first name, last name and the city and state of the office that they work out of (if they have one). Include all employees and order them by their first name, then their last name.

# %%
c.execute("""SELECT firstName, lastName, city, state
FROM employees
LEFT JOIN offices
USING(officeCode)
ORDER BY firstName, lastName""").fetchall()
# Out:
# [('Andy', 'Fixter', 'Sydney', ''),
#  ('Anthony', 'Bow', 'San Francisco', 'CA'),
#  ('Barry', 'Jones', 'London', ''),
#  ('Diane', 'Murphy', 'San Francisco', 'CA'),
#  ('Foon Yue', 'Tseng', 'NYC', 'NY'),
#  ('George', 'Vanauf', 'NYC', 'NY'),
#  ('Gerard', 'Bondur', 'Paris', ''),
#  ('Gerard', 'Hernandez', 'Paris', ''),
#  ('Jeff', 'Firrelli', 'San Francisco', 'CA'),
#  ('Julie', 'Firrelli', 'Boston', 'MA'),
#  ('Larry', 'Bott', 'London', ''),
#  ('Leslie', 'Jennings', 'San Francisco', 'CA'),
#  ('Leslie', 'Thompson', 'San Francisco', 'CA'),
#  ('Loui', 'Bondur', 'Paris', ''),
#  ('Mami', 'Nishi', 'Tokyo', 'Chiyoda-Ku'),
#  ('Martin', 'Gerard', 'Paris', ''),
#  ('Mary', 'Patterson', 'San Francisco', 'CA'),
#  ('Pamela', 'Castillo', 'Paris', ''),
#  ('Peter', 'Marsh', 'Sydney', ''),
#  ('Steve', 'Patterson', 'Boston', 'MA'),
#  ('Tom', 'King', 'Sydney', ''),
#  ('William', 'Patterson', 'Sydney', ''),
#  ('Yoshimi', 'Kato', 'Tokyo', 'Chiyoda-Ku')]

# %% [markdown]
# ## Customers and their Orders (a One-to-Many join)
#
# Return a list of all the customers first and last names along with a record for each of their order numbers, order dates and statuses.

# %%
c.execute("""SElECT contactFirstName, contactLastName, orderDate, orderNumber, status
            FROM customers
            LEFT JOIN orders
            USING(customerNumber)""").fetchall()
# Out:
# [('Atelier graphique', '2003-05-20', '10123', 'Shipped'),
#  ('Atelier graphique', '2004-09-27', '10298', 'Shipped'),
#  ('Atelier graphique', '2004-11-25', '10345', 'Shipped'),
#  ('Signal Gift Stores', '2003-05-21', '10124', 'Shipped'),
#  ('Signal Gift Stores', '2004-08-06', '10278', 'Shipped'),
#  ('Signal Gift Stores', '2004-11-29', '10346', 'Shipped'),
#  ('Australian Collectors, Co.', '2003-04-29', '10120', 'Shipped'),
#  ('Australian Collectors, Co.', '2003-05-21', '10125', 'Shipped'),
#  ('Australian Collectors, Co.', '2004-02-20', '10223', 'Shipped'),
#  ('Australian Collectors, Co.', '2004-11-24', '10342', 'Shipped'),
#  ('Australian Collectors, Co.', '2004-11-29', '10347', 'Shipped'),
#  ('La Rochelle Gifts', '2004-07-23', '10275', 'Shipped'),
#  ('La Rochelle Gifts', '2004-10-29', '10315', 'Shipped'),
#  ('La Rochelle Gifts', '2005-02-03', '10375', 'Shipped'),
#  ('La Rochelle Gifts', '2005-05-31', '10425', 'In Process'),
#  ('Baane Mini Imports', '2003-01-29', '10103', 'Shipped'),
#  ('Baane Mini Imports', '2003-10-10', '10158', 'Shipped'),
#  ('Baane Mini Imports', '2004-10-15', '10309', 'Shipped'),
#  ('Baane Mini Imports', '2004-11-05', '10325', 'Shipped'),
#  ('Mini Gifts Distributors Ltd.', '2003-03-26', '10113', 'Shipped'),
#  ('Mini Gifts Distributors Ltd.', '2003-07-02', '10135', 'Shipped'),
#  ('Mini Gifts Distributors Ltd.', '2003-08-08', '10142', 'Shipped'),
#  ('Mini Gifts Distributors Ltd.', '2003-11-12', '10182', 'Shipped'),
#  ('Mini Gifts Distributors Ltd.', '2004-03-11', '10229', 'Shipped'),
#  ('Mini Gifts Distributors Ltd.', '2004-07-20', '10271', 'Shipped'),
#  ('Mini Gifts Distributors Ltd.', '2004-08-20', '10282', 'Shipped'),
#  ('Mini Gifts Distributors Ltd.', '2004-10-21', '10312', 'Shipped'),
#  ('Mini Gifts Distributors Ltd.', '2004-11-19', '10335', 'Shipped'),
#  ('Mini Gifts Distributors Ltd.', '2004-12-10', '10357', 'Shipped'),
#  ('Mini Gifts Distributors Ltd.', '2005-01-19', '10368', 'Shipped'),
#  ('Mini Gifts Distributors Ltd.', '2005-01-23', '10371', 'Shipped'),
#  ('Mini Gifts Distributors Ltd.', '2005-02-17', '10382', 'Shipped'),
#  ('Mini Gifts Distributors Ltd.', '2005-02-28', '10385', 'Shipped'),
#  ('Mini Gifts Distributors Ltd.', '2005-03-04', '10390', 'Shipped'),
#  ('Mini Gifts Distributors Ltd.', '2005-03-23', '10396', 'Shipped'),
#  ('Mini Gifts Distributors Ltd.', '2005-05-29', '10421', 'In Process'),
#  ('Havel & Zbyszek Co', None, None, None),
#  ('Blauer See Auto, Co.', '2003-01-09', '10101', 'Shipped'),
#  ('Blauer See Auto, Co.', '2004-03-15', '10230', 'Shipped'),
#  ('Blauer See Auto, Co.', '2003-10-04', '10300', 'Shipped'),
#  ('Blauer See Auto, Co.', '2004-11-05', '10323', 'Shipped'),
#  ('Mini Wheels Co.', '2003-03-25', '10111', 'Shipped'),
#  ('Mini Wheels Co.', '2003-12-01', '10201', 'Shipped'),
#  ('Mini Wheels Co.', '2004-11-18', '10333', 'Shipped'),
#  ('Land of Toys Inc.', '2003-02-24', '10107', 'Shipped'),
#  ('Land of Toys Inc.', '2004-05-07', '10248', 'Cancelled'),
#  ('Land of Toys Inc.', '2004-09-08', '10292', 'Shipped'),
#  ('Land of Toys Inc.', '2004-11-15', '10329', 'Shipped'),
#  ('Euro+ Shopping Channel', '2003-01-31', '10104', 'Shipped'),
#  ('Euro+ Shopping Channel', '2003-06-06', '10128', 'Shipped'),
#  ('Euro+ Shopping Channel', '2003-06-27', '10133', 'Shipped'),
#  ('Euro+ Shopping Channel', '2003-09-28', '10153', 'Shipped'),
#  ('Euro+ Shopping Channel', '2003-10-08', '10156', 'Shipped'),
#  ('Euro+ Shopping Channel', '2003-11-19', '10190', 'Shipped'),
#  ('Euro+ Shopping Channel', '2003-12-02', '10203', 'Shipped'),
#  ('Euro+ Shopping Channel', '2003-12-03', '10205', 'Shipped'),
#  ('Euro+ Shopping Channel', '2004-01-16', '10212', 'Shipped'),
#  ('Euro+ Shopping Channel', '2004-04-29', '10244', 'Shipped'),
#  ('Euro+ Shopping Channel', '2004-05-05', '10246', 'Shipped'),
#  ('Euro+ Shopping Channel', '2004-06-24', '10262', 'Cancelled'),
#  ('Euro+ Shopping Channel', '2004-08-09', '10279', 'Shipped'),
#  ('Euro+ Shopping Channel', '2004-10-16', '10311', 'Shipped'),
#  ('Euro+ Shopping Channel', '2004-12-02', '10350', 'Shipped'),
#  ('Euro+ Shopping Channel', '2004-12-07', '10355', 'Shipped'),
#  ('Euro+ Shopping Channel', '2004-12-10', '10358', 'Shipped'),
#  ('Euro+ Shopping Channel', '2005-02-10', '10378', 'Shipped'),
#  ('Euro+ Shopping Channel', '2005-02-10', '10379', 'Shipped'),
#  ('Euro+ Shopping Channel', '2005-02-16', '10380', 'Shipped'),
#  ('Euro+ Shopping Channel', '2005-02-22', '10383', 'Shipped'),
#  ('Euro+ Shopping Channel', '2005-03-01', '10386', 'Resolved'),
#  ('Euro+ Shopping Channel', '2005-03-15', '10394', 'Shipped'),
#  ('Euro+ Shopping Channel', '2005-05-03', '10412', 'Shipped'),
#  ('Euro+ Shopping Channel', '2005-05-13', '10417', 'Disputed'),
#  ('Euro+ Shopping Channel', '2005-05-31', '10424', 'In Process'),
#  ('Volvo Model Replicas, Co', '2003-03-24', '10112', 'Shipped'),
#  ('Volvo Model Replicas, Co', '2004-11-03', '10320', 'Shipped'),
#  ('Volvo Model Replicas, Co', '2004-11-09', '10326', 'Shipped'),
#  ('Volvo Model Replicas, Co', '2004-11-19', '10334', 'On Hold'),
#  ('Danish Wholesale Imports', '2003-02-11', '10105', 'Shipped'),
#  ('Danish Wholesale Imports', '2004-04-09', '10238', 'Shipped'),
#  ('Danish Wholesale Imports', '2004-06-08', '10256', 'Shipped'),
#  ('Danish Wholesale Imports', '2004-11-10', '10327', 'Resolved'),
#  ('Danish Wholesale Imports', '2005-04-15', '10406', 'Disputed'),
#  ('Saveley & Henriot, Co.', '2003-11-25', '10194', 'Shipped'),
#  ('Saveley & Henriot, Co.', '2004-01-02', '10208', 'Shipped'),
#  ('Saveley & Henriot, Co.', '2004-03-02', '10227', 'Shipped'),
#  ('Dragon Souveniers, Ltd.', '2003-04-16', '10117', 'Shipped'),
#  ('Dragon Souveniers, Ltd.', '2003-09-19', '10150', 'Shipped'),
#  ('Dragon Souveniers, Ltd.', '2003-10-22', '10165', 'Shipped'),
#  ('Dragon Souveniers, Ltd.', '2004-08-04', '10277', 'Shipped'),
#  ('Dragon Souveniers, Ltd.', '2005-03-02', '10387', 'Shipped'),
#  ('Muscle Machine Inc', '2003-06-03', '10127', 'Shipped'),
#  ('Muscle Machine Inc', '2003-12-02', '10204', 'Shipped'),
#  ('Muscle Machine Inc', '2004-07-07', '10267', 'Shipped'),
#  ('Muscle Machine Inc', '2004-12-01', '10349', 'Shipped'),
#  ('Diecast Classics Inc.', '2004-07-20', '10272', 'Shipped'),
#  ('Diecast Classics Inc.', '2004-08-19', '10281', 'Shipped'),
#  ('Diecast Classics Inc.', '2004-11-02', '10318', 'Shipped'),
#  ('Diecast Classics Inc.', '2005-05-30', '10422', 'In Process'),
#  ('Technics Stores Inc.', '2003-07-24', '10140', 'Shipped'),
#  ('Technics Stores Inc.', '2003-10-28', '10168', 'Shipped'),
#  ('Technics Stores Inc.', '2004-11-02', '10317', 'Shipped'),
#  ('Technics Stores Inc.', '2005-01-05', '10362', 'Shipped'),
#  ('Handji Gifts& Co', '2004-02-04', '10217', 'Shipped'),
#  ('Handji Gifts& Co', '2004-06-15', '10259', 'Shipped'),
#  ('Handji Gifts& Co', '2004-09-01', '10288', 'Shipped'),
#  ('Handji Gifts& Co', '2005-04-23', '10409', 'Shipped'),
#  ('Herkku Gifts', '2003-11-12', '10181', 'Shipped'),
#  ('Herkku Gifts', '2003-11-18', '10188', 'Shipped'),
#  ('Herkku Gifts', '2004-09-03', '10289', 'Shipped'),
#  ('American Souvenirs Inc', None, None, None),
#  ('Porto Imports Co.', None, None, None),
#  ('Daedalus Designs Imports', '2003-11-11', '10180', 'Shipped'),
#  ('Daedalus Designs Imports', '2004-02-21', '10224', 'Shipped'),
#  ("La Corne D'abondance, Co.", '2003-04-01', '10114', 'Shipped'),
#  ("La Corne D'abondance, Co.", '2004-08-28', '10286', 'Shipped'),
#  ("La Corne D'abondance, Co.", '2004-11-20', '10336', 'Shipped'),
#  ('Cambridge Collectables Co.', '2004-03-10', '10228', 'Shipped'),
#  ('Cambridge Collectables Co.', '2004-05-08', '10249', 'Shipped'),
#  ('Gift Depot Inc.', '2003-11-05', '10172', 'Shipped'),
#  ('Gift Depot Inc.', '2004-06-28', '10263', 'Shipped'),
#  ('Gift Depot Inc.', '2005-05-05', '10413', 'Shipped'),
#  ('Osaka Souveniers Co.', '2004-01-12', '10210', 'Shipped'),
#  ('Osaka Souveniers Co.', '2004-04-13', '10240', 'Shipped'),
#  ('Vitachrome Inc.', '2003-01-10', '10102', 'Shipped'),
#  ('Vitachrome Inc.', '2004-04-05', '10237', 'Shipped'),
#  ('Vitachrome Inc.', '2004-11-05', '10324', 'Shipped'),
#  ('Toys of Finland, Co.', '2003-10-06', '10155', 'Shipped'),
#  ('Toys of Finland, Co.', '2004-09-30', '10299', 'Shipped'),
#  ('Toys of Finland, Co.', '2005-02-09', '10377', 'Shipped'),
#  ('AV Stores, Co.', '2003-03-18', '10110', 'Shipped'),
#  ('AV Stores, Co.', '2004-10-14', '10306', 'Shipped'),
#  ('AV Stores, Co.', '2004-11-17', '10332', 'Shipped'),
#  ('Clover Collections, Co.', '2004-02-12', '10220', 'Shipped'),
#  ('Clover Collections, Co.', '2004-09-16', '10297', 'Shipped'),
#  ('Auto-Moto Classics Inc.', '2003-06-16', '10130', 'Shipped'),
#  ('Auto-Moto Classics Inc.', '2004-09-07', '10290', 'Shipped'),
#  ('Auto-Moto Classics Inc.', '2004-12-03', '10352', 'Shipped'),
#  ('UK Collectables, Ltd.', '2004-06-01', '10253', 'Cancelled'),
#  ('UK Collectables, Ltd.', '2003-10-06', '10302', 'Shipped'),
#  ('UK Collectables, Ltd.', '2005-04-08', '10403', 'Shipped'),
#  ('Canadian Gift Exchange Network', '2003-12-05', '10206', 'Shipped'),
#  ('Canadian Gift Exchange Network', '2004-10-22', '10313', 'Shipped'),
#  ('Online Mini Collectables', '2004-08-02', '10276', 'Shipped'),
#  ('Online Mini Collectables', '2004-09-10', '10294', 'Shipped'),
#  ('Toys4GrownUps.com', '2003-08-25', '10145', 'Shipped'),
#  ('Toys4GrownUps.com', '2003-11-18', '10189', 'Shipped'),
#  ('Toys4GrownUps.com', '2005-01-12', '10367', 'Resolved'),
#  ('Asian Shopping Network, Co', None, None, None),
#  ('Mini Caravy', '2004-04-13', '10241', 'Shipped'),
#  ('Mini Caravy', '2004-06-04', '10255', 'Shipped'),
#  ('Mini Caravy', '2005-04-14', '10405', 'Shipped'),
#  ('King Kong Collectables, Co.', '2003-11-15', '10187', 'Shipped'),
#  ('King Kong Collectables, Co.', '2003-12-01', '10200', 'Shipped'),
#  ('Enaco Distributors', '2003-04-21', '10118', 'Shipped'),
#  ('Enaco Distributors', '2003-11-26', '10197', 'Shipped'),
#  ('Enaco Distributors', '2004-11-24', '10340', 'Shipped'),
#  ('Boards & Toys Co.', '2003-10-02', '10154', 'Shipped'),
#  ('Boards & Toys Co.', '2005-02-08', '10376', 'Shipped'),
#  ('Natürlich Autos', None, None, None),
#  ('Heintze Collectables', '2003-10-17', '10161', 'Shipped'),
#  ('Heintze Collectables', '2004-10-22', '10314', 'Shipped'),
#  ('Québec Home Shopping Network', '2003-11-05', '10171', 'Shipped'),
#  ('Québec Home Shopping Network', '2004-06-17', '10261', 'Shipped'),
#  ('Québec Home Shopping Network', '2005-05-01', '10411', 'Shipped'),
#  ('ANG Resellers', None, None, None),
#  ('Collectable Mini Designs Co.', '2004-02-19', '10222', 'Shipped'),
#  ('Collectable Mini Designs Co.', '2004-02-26', '10226', 'Shipped'),
#  ('giftsbymail.co.uk', '2004-03-20', '10232', 'Shipped'),
#  ('giftsbymail.co.uk', '2004-11-01', '10316', 'Shipped'),
#  ('Alpha Cognac', '2003-07-04', '10136', 'Shipped'),
#  ('Alpha Cognac', '2003-11-08', '10178', 'Shipped'),
#  ('Alpha Cognac', '2005-03-28', '10397', 'Shipped'),
#  ('Messner Shopping Network', None, None, None),
#  ('Amica Models & Co.', '2004-08-17', '10280', 'Shipped'),
#  ('Amica Models & Co.', '2004-09-09', '10293', 'Shipped'),
#  ('Lyon Souveniers', '2003-07-01', '10134', 'Shipped'),
#  ('Lyon Souveniers', '2004-12-09', '10356', 'Shipped'),
#  ('Lyon Souveniers', '2005-03-17', '10395', 'Shipped'),
#  ('Auto Associés & Cie.', '2004-02-02', '10216', 'Shipped'),
#  ('Auto Associés & Cie.', '2004-10-11', '10304', 'Shipped'),
#  ('Toms Spezialitäten, Ltd', '2003-11-20', '10191', 'Shipped'),
#  ('Toms Spezialitäten, Ltd', '2004-10-16', '10310', 'Shipped'),
#  ('Royal Canadian Collectables, Ltd.', '2004-04-02', '10235', 'Shipped'),
#  ('Royal Canadian Collectables, Ltd.', '2004-08-20', '10283', 'Shipped'),
#  ('Franken Gifts, Co', None, None, None),
#  ("Anna's Decorations, Ltd", '2003-09-11', '10148', 'Shipped'),
#  ("Anna's Decorations, Ltd", '2003-11-04', '10169', 'Shipped'),
#  ("Anna's Decorations, Ltd", '2005-01-20', '10370', 'Shipped'),
#  ("Anna's Decorations, Ltd", '2005-03-09', '10391', 'Shipped'),
#  ('Rovelli Gifts', '2003-02-17', '10106', 'Shipped'),
#  ('Rovelli Gifts', '2003-11-05', '10173', 'Shipped'),
#  ('Rovelli Gifts', '2004-11-12', '10328', 'Shipped'),
#  ('Souveniers And Things Co.', '2003-07-16', '10139', 'Shipped'),
#  ('Souveniers And Things Co.', '2004-07-19', '10270', 'Shipped'),
#  ('Souveniers And Things Co.', '2004-12-17', '10361', 'Shipped'),
#  ('Souveniers And Things Co.', '2005-05-29', '10420', 'In Process'),
#  ("Marta's Replicas Co.", '2004-08-27', '10285', 'Shipped'),
#  ("Marta's Replicas Co.", '2004-10-13', '10305', 'Shipped'),
#  ('BG&E Collectables', None, None, None),
#  ('Vida Sport, Ltd', '2004-02-22', '10225', 'Shipped'),
#  ('Vida Sport, Ltd', '2004-08-30', '10287', 'Shipped'),
#  ('Norway Gifts By Mail, Co.', '2004-08-21', '10284', 'Shipped'),
#  ('Norway Gifts By Mail, Co.', '2003-10-05', '10301', 'Shipped'),
#  ('Schuyler Imports', None, None, None),
#  ('Der Hund Imports', None, None, None),
#  ('Oulu Toy Supplies, Inc.', '2003-09-21', '10151', 'Shipped'),
#  ('Oulu Toy Supplies, Inc.', '2004-04-12', '10239', 'Shipped'),
#  ('Oulu Toy Supplies, Inc.', '2005-01-31', '10373', 'Shipped'),
#  ('Petit Auto', '2004-02-18', '10221', 'Shipped'),
#  ('Petit Auto', '2004-07-21', '10273', 'Shipped'),
#  ('Petit Auto', '2005-05-30', '10423', 'In Process'),
#  ('Mini Classics', '2003-11-25', '10195', 'Shipped'),
#  ('Mini Classics', '2004-10-15', '10308', 'Shipped'),
#  ('Mini Creations Ltd.', '2003-08-10', '10143', 'Shipped'),
#  ('Mini Creations Ltd.', '2003-11-14', '10185', 'Shipped'),
#  ('Mini Creations Ltd.', '2005-01-07', '10365', 'Shipped'),
#  ('Corporate Gift Ideas Co.', '2003-10-10', '10159', 'Shipped'),
#  ('Corporate Gift Ideas Co.', '2003-10-18', '10162', 'Shipped'),
#  ('Corporate Gift Ideas Co.', '2005-02-17', '10381', 'Shipped'),
#  ('Corporate Gift Ideas Co.', '2005-02-23', '10384', 'Shipped'),
#  ('Down Under Souveniers, Inc', '2003-06-25', '10132', 'Shipped'),
#  ('Down Under Souveniers, Inc', '2004-06-03', '10254', 'Shipped'),
#  ('Down Under Souveniers, Inc', '2004-12-04', '10354', 'Shipped'),
#  ('Down Under Souveniers, Inc', '2005-03-11', '10393', 'Shipped'),
#  ('Down Under Souveniers, Inc', '2005-04-08', '10404', 'Shipped'),
#  ('Stylish Desk Decors, Co.', '2003-06-12', '10129', 'Shipped'),
#  ('Stylish Desk Decors, Co.', '2003-11-06', '10175', 'Shipped'),
#  ('Stylish Desk Decors, Co.', '2004-12-03', '10351', 'Shipped'),
#  ('Tekni Collectables Inc.', '2004-03-29', '10233', 'Shipped'),
#  ('Tekni Collectables Inc.', '2004-05-18', '10251', 'Shipped'),
#  ('Tekni Collectables Inc.', '2005-04-03', '10401', 'On Hold'),
#  ('Australian Gift Network, Co', '2003-09-25', '10152', 'Shipped'),
#  ('Australian Gift Network, Co', '2003-11-06', '10174', 'Shipped'),
#  ('Australian Gift Network, Co', '2005-02-02', '10374', 'Shipped'),
#  ('Suominen Souveniers', '2003-08-01', '10141', 'Shipped'),
#  ('Suominen Souveniers', '2004-05-05', '10247', 'Shipped'),
#  ('Suominen Souveniers', '2005-01-06', '10363', 'Shipped'),
#  ('Cramer Spezialitäten, Ltd', None, None, None),
#  ('Classic Gift Ideas, Inc', '2003-11-13', '10183', 'Shipped'),
#  ('Classic Gift Ideas, Inc', '2004-10-14', '10307', 'Shipped'),
#  ('CAF Imports', '2003-11-07', '10177', 'Shipped'),
#  ('CAF Imports', '2004-03-19', '10231', 'Shipped'),
#  ("Men 'R' US Retailers, Ltd.", '2003-10-11', '10160', 'Shipped'),
#  ("Men 'R' US Retailers, Ltd.", '2004-01-09', '10209', 'Shipped'),
#  ('Asian Treasures, Inc.', None, None, None),
#  ('Marseille Mini Autos', '2003-05-08', '10122', 'Shipped'),
#  ('Marseille Mini Autos', '2004-11-25', '10344', 'Shipped'),
#  ('Marseille Mini Autos', '2005-01-06', '10364', 'Shipped'),
#  ('Reims Collectables', '2003-05-07', '10121', 'Shipped'),
#  ('Reims Collectables', '2003-07-10', '10137', 'Shipped'),
#  ('Reims Collectables', '2004-11-24', '10343', 'Shipped'),
#  ('Reims Collectables', '2004-12-15', '10359', 'Shipped'),
#  ('Reims Collectables', '2005-03-30', '10398', 'Shipped'),
#  ('SAR Distributors, Co', None, None, None),
#  ('GiftsForHim.com', '2003-12-02', '10202', 'Shipped'),
#  ('GiftsForHim.com', '2004-06-16', '10260', 'Cancelled'),
#  ('GiftsForHim.com', '2005-04-29', '10410', 'Shipped'),
#  ('Kommission Auto', None, None, None),
#  ('Gifts4AllAges.com', '2004-06-30', '10264', 'Shipped'),
#  ('Gifts4AllAges.com', '2004-09-10', '10295', 'Shipped'),
#  ('Gifts4AllAges.com', '2005-05-06', '10414', 'On Hold'),
#  ('Online Diecast Creations Co.', '2003-01-06', '10100', 'Shipped'),
#  ('Online Diecast Creations Co.', '2003-11-20', '10192', 'Shipped'),
#  ('Online Diecast Creations Co.', '2004-11-04', '10322', 'Shipped'),
#  ('Lisboa Souveniers, Inc', None, None, None),
#  ('Precious Collectables', None, None, None),
#  ('Collectables For Less Inc.', '2003-09-05', '10147', 'Shipped'),
#  ('Collectables For Less Inc.', '2004-07-21', '10274', 'Shipped'),
#  ('Collectables For Less Inc.', '2005-01-20', '10369', 'Shipped'),
#  ('Royale Belge', '2003-04-11', '10116', 'Shipped'),
#  ('Royale Belge', '2003-08-13', '10144', 'Shipped'),
#  ('Royale Belge', '2004-11-22', '10338', 'Shipped'),
#  ('Royale Belge', '2005-01-10', '10366', 'Shipped'),
#  ('Salzburg Collectables', '2003-04-28', '10119', 'Shipped'),
#  ('Salzburg Collectables', '2004-07-16', '10269', 'Shipped'),
#  ('Salzburg Collectables', '2004-11-24', '10341', 'Shipped'),
#  ('Salzburg Collectables', '2005-05-17', '10419', 'Shipped'),
#  ('Cruz & Sons Co.', '2003-03-03', '10108', 'Shipped'),
#  ('Cruz & Sons Co.', '2003-11-27', '10198', 'Shipped'),
#  ('Cruz & Sons Co.', '2004-11-16', '10330', 'Shipped'),
#  ("L'ordine Souveniers", '2003-11-06', '10176', 'Shipped'),
#  ("L'ordine Souveniers", '2004-07-06', '10266', 'Shipped'),
#  ("L'ordine Souveniers", '2005-05-10', '10416', 'Shipped'),
#  ('Tokyo Collectables, Ltd', '2004-06-15', '10258', 'Shipped'),
#  ('Tokyo Collectables, Ltd', '2004-11-23', '10339', 'Shipped'),
#  ('Tokyo Collectables, Ltd', '2005-01-26', '10372', 'Shipped'),
#  ('Tokyo Collectables, Ltd', '2005-04-22', '10408', 'Shipped'),
#  ('Auto Canal+ Petit', '2004-01-15', '10211', 'Shipped'),
#  ('Auto Canal+ Petit', '2004-05-26', '10252', 'Shipped'),
#  ('Auto Canal+ Petit', '2005-04-07', '10402', 'Shipped'),
#  ('Stuttgart Collectable Exchange', None, None, None),
#  ('Extreme Desk Decorations, Ltd', '2004-03-30', '10234', 'Shipped'),
#  ('Extreme Desk Decorations, Ltd', '2004-07-12', '10268', 'Shipped'),
#  ('Extreme Desk Decorations, Ltd', '2005-05-16', '10418', 'Shipped'),
#  ('Bavarian Collectables Imports, Co.', '2004-09-15', '10296', 'Shipped'),
#  ('Classic Legends Inc.', '2003-04-04', '10115', 'Shipped'),
#  ('Classic Legends Inc.', '2003-10-20', '10163', 'Shipped'),
#  ('Classic Legends Inc.', '2004-11-21', '10337', 'Shipped'),
#  ('Feuer Online Stores, Inc', None, None, None),
#  ('Gift Ideas Corp.', '2003-06-16', '10131', 'Shipped'),
#  ('Gift Ideas Corp.', '2003-09-03', '10146', 'Shipped'),
#  ('Gift Ideas Corp.', '2004-12-04', '10353', 'Shipped'),
#  ('Scandinavian Gift Ideas', '2003-10-23', '10167', 'Cancelled'),
#  ('Scandinavian Gift Ideas', '2004-09-08', '10291', 'Shipped'),
#  ('Scandinavian Gift Ideas', '2005-03-03', '10389', 'Shipped'),
#  ('The Sharp Gifts Warehouse', '2004-05-11', '10250', 'Shipped'),
#  ('The Sharp Gifts Warehouse', '2004-06-14', '10257', 'Shipped'),
#  ('The Sharp Gifts Warehouse', '2005-04-01', '10400', 'Shipped'),
#  ('The Sharp Gifts Warehouse', '2005-04-22', '10407', 'On Hold'),
#  ('Mini Auto Werke', '2003-10-21', '10164', 'Resolved'),
#  ('Mini Auto Werke', '2003-11-04', '10170', 'Shipped'),
#  ('Mini Auto Werke', '2005-03-10', '10392', 'Shipped'),
#  ('Super Scale Inc.', '2003-11-26', '10196', 'Shipped'),
#  ('Super Scale Inc.', '2004-05-04', '10245', 'Shipped'),
#  ('Microscale Inc.', '2004-04-20', '10242', 'Shipped'),
#  ('Microscale Inc.', '2004-11-03', '10319', 'Shipped'),
#  ('Corrida Auto Replicas, Ltd', '2003-05-28', '10126', 'Shipped'),
#  ('Corrida Auto Replicas, Ltd', '2004-01-26', '10214', 'Shipped'),
#  ('Corrida Auto Replicas, Ltd', '2004-11-01', '10348', 'Shipped'),
#  ('Warburg Exchange', None, None, None),
#  ('FunGiftIdeas.com', '2003-10-21', '10166', 'Shipped'),
#  ('FunGiftIdeas.com', '2004-11-04', '10321', 'Shipped'),
#  ('FunGiftIdeas.com', '2005-03-03', '10388', 'Shipped'),
#  ('Anton Designs, Ltd.', None, None, None),
#  ('Australian Collectables, Ltd', '2003-11-21', '10193', 'Shipped'),
#  ('Australian Collectables, Ltd', '2004-07-02', '10265', 'Shipped'),
#  ('Australian Collectables, Ltd', '2005-05-09', '10415', 'Disputed'),
#  ('Frau da Collezione', '2003-10-09', '10157', 'Shipped'),
#  ('Frau da Collezione', '2004-02-09', '10218', 'Shipped'),
#  ('West Coast Collectables Co.', '2003-12-01', '10199', 'Shipped'),
#  ('West Coast Collectables Co.', '2004-01-29', '10215', 'Shipped'),
#  ('Mit Vergnügen & Co.', None, None, None),
#  ('Kremlin Collectables, Co.', None, None, None),
#  ('Raanan Stores, Inc', None, None, None),
#  ('Iberia Gift Imports, Corp.', '2003-11-14', '10184', 'Shipped'),
#  ('Iberia Gift Imports, Corp.', '2004-10-06', '10303', 'Shipped'),
#  ('Motor Mint Distributors Inc.', '2003-03-10', '10109', 'Shipped'),
#  ('Motor Mint Distributors Inc.', '2004-04-03', '10236', 'Shipped'),
#  ('Motor Mint Distributors Inc.', '2004-11-17', '10331', 'Shipped'),
#  ('Signal Collectibles Ltd.', '2003-09-12', '10149', 'Shipped'),
#  ('Signal Collectibles Ltd.', '2004-02-10', '10219', 'Shipped'),
#  ('Double Decker Gift Stores, Ltd', '2003-11-14', '10186', 'Shipped'),
#  ('Double Decker Gift Stores, Ltd', '2004-01-22', '10213', 'Shipped'),
#  ('Diecast Collectables', '2003-12-09', '10207', 'Shipped'),
#  ('Diecast Collectables', '2004-04-26', '10243', 'Shipped'),
#  ("Kelly's Gift Shop", '2003-07-07', '10138', 'Shipped'),
#  ("Kelly's Gift Shop", '2003-11-11', '10179', 'Cancelled'),
#  ("Kelly's Gift Shop", '2004-12-16', '10360', 'Shipped'),
#  ("Kelly's Gift Shop", '2005-04-01', '10399', 'Shipped')]

# %% [markdown]
# ## Customers and their Payments (another One-to-Many join)
#
# Return a list of customers first and last names along with details about their payments including the amount and date of payments. Sort these results in descending order by the payment amount.

# %%
# Your code here

# %% [markdown]
# ## Orders, Order details and Product Details (a Many-to-Many Join)

# %% [markdown]
# Return a list of customer first and last names, product names, quantities, and date ordered for each of the customers and each of their orders. Sort these in descending order by the order date.
#
# Note: This will require joining 4 tables! This can be tricky! Give it a shot, and if you're still stuck, turn to the next section where you'll see how to write subqueries which can make complex queries such as this much simpler!

# %%
# Your code here

# %% [markdown]
# ## Summary

# %% [markdown]
# In this lab, you practiced your knowledge on one-to-many and many-to-many relationships!
